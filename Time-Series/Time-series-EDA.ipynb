# %%
## Install Pandas Data Reader
# !pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: lxml in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas-datareader) (5.3.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas-datareader) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas-datareader) (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.50-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2024.1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.8.tar.gz (948 kB)
#      ---------------------------------------- 0.0/948.2 kB ? eta -:--:--
#      -------------------------------------- 948.2/948.2 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amritanshu bhardwaj\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Downloading yfinance-0.2.50-py2.py3-none-any.whl (102 kB)
# Downloading frozendict-2.4.6-py312-none-any.whl (16 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.8-py3-none-any.whl size=139013 sha256=8e7a44fb11afdbc881a6c2ae8765be1977cd88a8dd054ef82177efdc0552fa4d
#   Stored in directory: c:\users\amritanshu bhardwaj\appdata\local\pip\cache\wheels\8f\65\34\456800445efeafb05164fe95285c70e81ba1d96bae30f43917
# Successfully built peewee
# Installing collected packages: peewee, multitasking, frozendict, yfinance
# Successfully installed frozendict-2.4.6 multitasking-0.0.11 peewee-3.17.8 yfinance-0.2.50

# %%
import yfinance as yf
# Fetch Tesla stock data
df_tsla = yf.download('TSLA')  ## Stock data
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(df_tsla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tsla.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.074000  1.333333  1.055333  1.333333  103003500

# %%
df_tsla.tail()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2024-11-13  330.239990  330.239990  344.600006  322.500000  335.850006
# 2024-11-14  311.179993  311.179993  329.980011  310.369995  327.690002
# 2024-11-15  320.720001  320.720001  324.679993  309.220001  310.570007
# 2024-11-18  338.739990  338.739990  348.549988  330.010010  340.730011
# 2024-11-19  346.000000  346.000000  347.380005  332.750000  335.760010
#
# Price          Volume
# Ticker           TSLA
# Date
# 2024-11-13  125405600
# 2024-11-14  120726100
# 2024-11-15  114440300
# 2024-11-18  126547500
# 2024-11-19   88563400

# %%
df_tsla.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit
df_tsla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4)) ##start and end state specify kiya
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit
df_tsla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,800],figsize=(12,4))
## y ke direction me values specify ki
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit and coloring
df_tsla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,800],figsize=(12,4),c='green')
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit and coloring and linestyle
df_tsla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,800],figsize=(12,4),c='green',ls='--')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-11-06', '2024-11-07', '2024-11-08', '2024-11-11',
#                '2024-11-12', '2024-11-13', '2024-11-14', '2024-11-15',
#                '2024-11-18', '2024-11-19'],
#               dtype='datetime64[ns]', name='Date', length=3624, freq=None)

# %%
## How to read specific indexes (values at specific dates)
df_tsla.loc['2020-01-01':'2021-09-01']  #index based reading (iss date se uss date tak)
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2020-01-02   28.684000   28.684000   28.713333   28.114000   28.299999
# 2020-01-03   29.534000   29.534000   30.266666   29.128000   29.366667
# 2020-01-06   30.102667   30.102667   30.104000   29.333332   29.364668
# 2020-01-07   31.270666   31.270666   31.441999   30.224001   30.760000
# 2020-01-08   32.809334   32.809334   33.232666   31.215334   31.580000
# ...                ...         ...         ...         ...         ...
# 2021-08-26  233.720001  233.720001  238.466660  232.539993  236.103333
# 2021-08-27  237.306671  237.306671  238.333328  234.033340  235.000000
# 2021-08-30  243.636673  243.636673  243.666672  237.576660  238.240005
# 2021-08-31  245.240005  245.240005  246.796661  242.146667  244.333328
# 2021-09-01  244.696671  244.696671  247.330002  243.756668  244.693329
#
# Price          Volume
# Ticker           TSLA
# Date
# 2020-01-02  142981500
# 2020-01-03  266677500
# 2020-01-06  151995000
# 2020-01-07  268231500
# 2020-01-08  467164500
# ...               ...
# 2021-08-26   39642900
# 2021-08-27   41501400
# 2021-08-30   55812600
# 2021-08-31   62566200
# 2021-09-01   39612900
#
# [421 rows x 6 columns]

# %%
df_tsla.loc['2020-01-01':'2021-09-01'].index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
index = df_tsla.loc['2020-01-01':'2021-09-01'].index
share_open = df_tsla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Ticker            TSLA
# Date
# 2020-01-02   28.299999
# 2020-01-03   29.366667
# 2020-01-06   29.364668
# 2020-01-07   30.760000
# 2020-01-08   31.580000
# ...                ...
# 2021-08-26  236.103333
# 2021-08-27  235.000000
# 2021-08-30  238.240005
# 2021-08-31  244.333328
# 2021-09-01  244.693329
#
# [421 rows x 1 columns]

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis = plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()  ##taki x axis ki value display hone me overlap na kare
# Auto formating x date is actually preventing overlapping
axis.plot(index,share_open)

# %%
## Datetime Index

# %%
df_tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3624 entries, 2010-06-29 to 2024-11-19
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, TSLA)  3624 non-null   float64
#  1   (Close, TSLA)      3624 non-null   float64
#  2   (High, TSLA)       3624 non-null   float64
#  3   (Low, TSLA)        3624 non-null   float64
#  4   (Open, TSLA)       3624 non-null   float64
#  5   (Volume, TSLA)     3624 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 327.2 KB

# %%
df_tsla.reset_index()  ## Here u are getting date_time as a seperate column
## Date is the index here
# Out:
# Price        Date   Adj Close       Close        High         Low        Open  \
# Ticker                   TSLA        TSLA        TSLA        TSLA        TSLA
# 0      2010-06-29    1.592667    1.592667    1.666667    1.169333    1.266667
# 1      2010-06-30    1.588667    1.588667    2.028000    1.553333    1.719333
# 2      2010-07-01    1.464000    1.464000    1.728000    1.351333    1.666667
# 3      2010-07-02    1.280000    1.280000    1.540000    1.247333    1.533333
# 4      2010-07-06    1.074000    1.074000    1.333333    1.055333    1.333333
# ...           ...         ...         ...         ...         ...         ...
# 3619   2024-11-13  330.239990  330.239990  344.600006  322.500000  335.850006
# 3620   2024-11-14  311.179993  311.179993  329.980011  310.369995  327.690002
# 3621   2024-11-15  320.720001  320.720001  324.679993  309.220001  310.570007
# 3622   2024-11-18  338.739990  338.739990  348.549988  330.010010  340.730011
# 3623   2024-11-19  346.000000  346.000000  347.380005  332.750000  335.760010
#
# Price      Volume
# Ticker       TSLA
# 0       281494500
# 1       257806500
# 2       123282000
# 3        77097000
# 4       103003500
# ...           ...
# 3619    125405600
# 3620    120726100
# 3621    114440300
# 3622    126547500
# 3623     88563400
#
# [3624 rows x 7 columns]

# %%
df_tsla = df_tsla.reset_index()

# %%
df_tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3624 entries, 0 to 3623
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Date, )           3624 non-null   datetime64[ns]
#  1   (Adj Close, TSLA)  3624 non-null   float64
#  2   (Close, TSLA)      3624 non-null   float64
#  3   (High, TSLA)       3624 non-null   float64
#  4   (Low, TSLA)        3624 non-null   float64
#  5   (Open, TSLA)       3624 non-null   float64
#  6   (Volume, TSLA)     3624 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 198.3 KB

# %%
pd.to_datetime(df_tsla['Date']) ## Date in dataset was given in string format we converted it to datetime
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 3619   2024-11-13
# 3620   2024-11-14
# 3621   2024-11-15
# 3622   2024-11-18
# 3623   2024-11-19
# Name: Date, Length: 3624, dtype: datetime64[ns]

# %%
df_tsla  ## Here u will see that date is not an index anymore as we reseted the index
# (Originally it was index)
# Out:
# Price        Date   Adj Close       Close        High         Low        Open  \
# Ticker                   TSLA        TSLA        TSLA        TSLA        TSLA
# 0      2010-06-29    1.592667    1.592667    1.666667    1.169333    1.266667
# 1      2010-06-30    1.588667    1.588667    2.028000    1.553333    1.719333
# 2      2010-07-01    1.464000    1.464000    1.728000    1.351333    1.666667
# 3      2010-07-02    1.280000    1.280000    1.540000    1.247333    1.533333
# 4      2010-07-06    1.074000    1.074000    1.333333    1.055333    1.333333
# ...           ...         ...         ...         ...         ...         ...
# 3619   2024-11-13  330.239990  330.239990  344.600006  322.500000  335.850006
# 3620   2024-11-14  311.179993  311.179993  329.980011  310.369995  327.690002
# 3621   2024-11-15  320.720001  320.720001  324.679993  309.220001  310.570007
# 3622   2024-11-18  338.739990  338.739990  348.549988  330.010010  340.730011
# 3623   2024-11-19  346.000000  346.000000  347.380005  332.750000  335.760010
#
# Price      Volume
# Ticker       TSLA
# 0       281494500
# 1       257806500
# 2       123282000
# 3        77097000
# 4       103003500
# ...           ...
# 3619    125405600
# 3620    120726100
# 3621    114440300
# 3622    126547500
# 3623     88563400
#
# [3624 rows x 7 columns]

# %%
## To make date as index 
df_tsla.set_index('Date',drop=True) ## don't forget to keep drop true, telling ki kis column ko 
# index banana hai
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2010-06-29    1.592667    1.592667    1.666667    1.169333    1.266667
# 2010-06-30    1.588667    1.588667    2.028000    1.553333    1.719333
# 2010-07-01    1.464000    1.464000    1.728000    1.351333    1.666667
# 2010-07-02    1.280000    1.280000    1.540000    1.247333    1.533333
# 2010-07-06    1.074000    1.074000    1.333333    1.055333    1.333333
# ...                ...         ...         ...         ...         ...
# 2024-11-13  330.239990  330.239990  344.600006  322.500000  335.850006
# 2024-11-14  311.179993  311.179993  329.980011  310.369995  327.690002
# 2024-11-15  320.720001  320.720001  324.679993  309.220001  310.570007
# 2024-11-18  338.739990  338.739990  348.549988  330.010010  340.730011
# 2024-11-19  346.000000  346.000000  347.380005  332.750000  335.760010
#
# Price          Volume
# Ticker           TSLA
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# 2010-07-02   77097000
# 2010-07-06  103003500
# ...               ...
# 2024-11-13  125405600
# 2024-11-14  120726100
# 2024-11-15  114440300
# 2024-11-18  126547500
# 2024-11-19   88563400
#
# [3624 rows x 6 columns]

# %%
df_tsla = df_tsla.set_index('Date',drop=True)

# %%
df_tsla.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.074000  1.333333  1.055333  1.333333  103003500

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 11, 20, 10, 39, 33, 82056)

# %%
def add_num(num1,num2):
    return num1+num2

# %%
start_time = datetime.now()
num1 = 20
num2 = 30

add_num(num1,num2)
end_time = datetime.now()
print(end_time-start_time)  ##matlab ye addition wala operation 0 time me really fast execute 
# ho rha hai
# Out:
# 0:00:00

# %%
start_time = datetime.now()
num1 = 20
num2 = 30
for i in [1,2,3,4,5]:
    add_num(num1,num2)
end_time = datetime.now()
print(end_time-start_time)
# Out:
# 0:00:00.001000

# %%
date = datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %% [markdown]
# Time Resampling

# %%
df_tsla.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.074000  1.333333  1.055333  1.333333  103003500

# %%
df_tsla.resample(rule='A')
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\513246966.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tsla.resample(rule='A')

# %%
df_tsla.resample(rule='A').min()
#Ye aapko harr year ke harr ek attribute/instance/feature ki minimum value dega
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\3050570558.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tsla.resample(rule='A').min()
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2010-12-31    1.053333    1.053333    1.108667    0.998667    1.076000
# 2011-12-31    1.455333    1.455333    1.484667    1.407333    1.452000
# 2012-12-31    1.519333    1.519333    1.790000    1.509333    1.774667
# 2013-12-31    2.194000    2.194000    2.225333    2.140667    2.205333
# 2014-12-31    9.289333    9.289333    9.800000    9.111333    9.366667
# 2015-12-31   12.333333   12.333333   12.619333   12.093333   12.388667
# 2016-12-31    9.578000    9.578000   10.331333    9.403333    9.488000
# 2017-12-31   14.466000   14.466000   14.688667   14.064000   14.316667
# 2018-12-31   16.704000   16.704000   17.355333   16.306000   16.851999
# 2019-12-31   11.931333   11.931333   12.445333   11.799333   12.073333
# 2020-12-31   24.081333   24.081333   26.990667   23.367332   24.980000
# 2021-12-31  187.666672  187.666672  188.736664  179.830002  184.183334
# 2022-12-31  109.099998  109.099998  116.269997  108.239998  110.349998
# 2023-12-31  108.099998  108.099998  111.750000  101.809998  103.000000
# 2024-12-31  142.050003  142.050003  144.440002  138.800003  140.559998
#
# Price         Volume
# Ticker          TSLA
# Date
# 2010-12-31   1777500
# 2011-12-31   3594000
# 2012-12-31   5473500
# 2013-12-31   6603000
# 2014-12-31  19983000
# 2015-12-31  10620000
# 2016-12-31  24892500
# 2017-12-31  32800500
# 2018-12-31  46210500
# 2019-12-31  36984000
# 2020-12-31  52073100
# 2021-12-31  29401800
# 2022-12-31  41864700
# 2023-12-31  65125200
# 2024-12-31  43268700

# %%
df_tsla.resample(rule='A').max()
#Ye aapko harr year ke harr ek attribute/instance/feature ki maximum value dega
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\53427381.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tsla.resample(rule='A').max()
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2010-12-31    2.364667    2.364667    2.428000    2.316667    2.391333
# 2011-12-31    2.329333    2.329333    2.333333    2.268667    2.308667
# 2012-12-31    2.534000    2.534000    2.663333    2.474000    2.546000
# 2013-12-31   12.891333   12.891333   12.966667   12.558000   12.930667
# 2014-12-31   19.069332   19.069332   19.427999   18.693333   19.177999
# 2015-12-31   18.817333   18.817333   19.110001   18.420000   18.680000
# 2016-12-31   17.694668   17.694668   17.955999   16.967333   17.763332
# 2017-12-31   25.666668   25.666668   25.974001   25.290001   25.779333
# 2018-10-01  411382500
# 2019-01-01  362262000
# 2019-04-01  398206500
# 2019-07-01  336274500
# 2019-10-01  450091500
# 2020-01-01  914082000
# 2020-04-01  487977000
# 2020-07-01  584781000
# 2020-10-01  666378600
# 2021-01-01  268189500
# 2021-04-01  147052200
# 2021-07-01  100847400
# 2021-10-01  188556300
# 2022-01-01  151565700
# 2022-04-01  144973200
# 2022-07-01  142032300
# 2022-10-01  221923300
# 2023-01-01  306590600
# 2023-04-01  211797100
# 2023-07-01  175158300
# 2023-10-01  170772700
# 2024-01-01  198076800
# 2024-04-01  243869700
# 2024-07-01  221707300
# 2024-10-01  210521600

# %%
df_tsla.resample(rule='QS').max()['High'].plot()
## Quaterly high(instance) ka plot karna (max ko(of high))
# Out:
# <Axes: xlabel='Date'>

# %%
## Business End Frequency
df_tsla.resample(rule='BA').max()['High'].plot()
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\4002247497.py:2: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tsla.resample(rule='BA').max()['High'].plot()
# <Axes: xlabel='Date'>

# %%
df_tsla.resample(rule='BA').max() ##Since its end frequency so from here bussiness is ending
## u can see 31'st 29'th in end date
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\2435290269.py:1: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tsla.resample(rule='BA').max()
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2010-12-31    2.364667    2.364667    2.428000    2.316667    2.391333
# 2011-12-30    2.329333    2.329333    2.333333    2.268667    2.308667
# 2012-12-31    2.534000    2.534000    2.663333    2.474000    2.546000
# 2013-12-31   12.891333   12.891333   12.966667   12.558000   12.930667
# 2014-12-31   19.069332   19.069332   19.427999   18.693333   19.177999
# 2015-12-31   18.817333   18.817333   19.110001   18.420000   18.680000
# 2016-12-30   17.694668   17.694668   17.955999   16.967333   17.763332
# 2017-12-29   25.666668   25.666668   25.974001   25.290001   25.779333
# 2018-12-31   25.304667   25.304667   25.830667   24.474667   25.000000
# 2019-12-31   28.729334   28.729334   29.020666   28.423332   29.000000
# 2020-12-31  235.223328  235.223328  239.573334  230.373337  233.330002
# 2021-12-31  409.970001  409.970001  414.496674  405.666656  411.470001
# 2022-12-30  399.926666  399.926666  402.666656  378.679993  396.516663
# 2023-12-29  293.339996  293.339996  299.290009  289.519989  296.040009
# 2024-12-31  350.000000  350.000000  358.640015  336.000000  346.299988
#
# Price          Volume
# Ticker           TSLA
# Date
# 2010-12-31  281494500
# 2011-12-30  172767000
# 2012-12-31   85206000
# 2013-12-31  557458500
# 2014-12-31  490225500
# 2015-12-31  234744000
# 2016-12-30  356136000
# 2017-12-29  296871000
# 2018-12-31  504745500
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-30  221923300
# 2023-12-29  306590600
# 2024-12-31  243869700

# %%
## Bussiness quaterly start
## from here bussinesses are getting start so here u can see start date
df_tsla.resample(rule='BQS').max()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2010
# 2023-01-02  214.240005  214.240005  217.649994  206.110001  211.759995
# 2023-04-03  274.450012  274.450012  276.989990  261.119995  275.130005
# 2023-07-03  293.339996  293.339996  299.290009  289.519989  296.040009
# 2023-10-02  263.619995  263.619995  268.940002  260.899994  266.200012
# 2024-01-01  248.419998  248.419998  251.250000  244.410004  250.080002
# 2024-04-01  197.880005  197.880005  203.199997  195.259995  199.550003
# 2024-07-01  263.260010  263.260010  271.000000  257.859985  263.299988
# 2024-10-01  350.000000  350.000000  358.640015  336.000000  346.299988
#
# Price          Volume
# Ticker           TSLA
# Date
# 2010-04-01  281494500
# 2010-07-01  123282000
# 2010-10-01  139528500
# 2011-01-03  172767000
# 2011-04-01   93138000
# 2011-07-01   45967500
# 2011-10-03   58024500
# 2012-01-02   82506000
# 2012-04-02   83344500
# 2012-07-02   85206000
# 2012-10-01   34860000
# 2013-01-01  135567000
# 2013-04-01  557458500
# 2013-07-01  485578500
# 2013-10-01  466075500
# 2014-01-01  490225500
# 2014-04-01  300849000
# 2014-07-01  246831000
# 2014-10-01  230320500
# 2015-01-01  234744000
# 2015-04-01  186837000
# 2015-07-01  219357000
# 2015-10-01  223500000
# 2016-01-01  213786000
# 2016-04-01  356136000
# 2016-07-01  119146500
# 2016-10-03  196405500
# 2017-01-02  223728000
# 2017-04-03  258921000
# 2017-07-03  289867500
# 2017-10-02  296871000
# 2018-01-01  315021000
# 2018-04-02  335211000
# 2018-07-02  504745500
# 2018-10-01  411382500
# 2019-01-01  362262000
# 2019-04-01  398206500
# 2019-07-01  336274500
# 2019-10-01  450091500
# 2020-01-01  914082000
# 2020-04-01  487977000
# 2020-07-01  584781000
# 2020-10-01  666378600
# 2021-01-01  268189500
# 2021-04-01  147052200
# 2021-07-01  100847400
# 2021-10-01  188556300
# 2022-01-03  151565700
# 2022-04-01  144973200
# 2022-07-01  142032300
# 2022-10-03  221923300
# 2023-01-02  306590600
# 2023-04-03  211797100
# 2023-07-03  175158300
# 2023-10-02  170772700
# 2024-01-01  198076800
# 2024-04-01  243869700
# 2024-07-01  221707300
# 2024-10-01  210521600

# %%
## Plotting
df_tsla['Open'].resample(rule='BA').mean().plot(kind='bar')
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\1605789893.py:2: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tsla['Open'].resample(rule='BA').mean().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
df_tsla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\3647761295.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tsla['Open'].resample(rule='A').mean().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
df_tsla['Open'].resample(rule='M').mean()
## Help us to get monthly mean(u can do for any instance also)
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\1875486734.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tsla['Open'].resample(rule='M').mean()
# Ticker            TSLA
# Date
# 2010-06-30    1.493000
# 2010-07-31    1.338222
# 2010-08-31    1.303030
# 2010-09-30    1.385270
# 2010-10-31    1.381556
# ...                ...
# 2024-07-31  239.729544
# 2024-08-31  209.370911
# 2024-09-30  234.301501
# 2024-10-31  239.483479
# 2024-11-30  304.329234
#
# [174 rows x 1 columns]

# %%
df_tsla['Open'].resample(rule='M').max()
## Help us to get monthly max(u can do for any instance also)
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\481364103.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tsla['Open'].resample(rule='M').max()
# Ticker            TSLA
# Date
# 2010-06-30    1.719333
# 2010-07-31    1.666667
# 2010-08-31    1.463333
# 2010-09-30    1.476667
# 2010-10-31    1.426000
# ...                ...
# 2024-07-31  263.299988
# 2024-08-31  227.690002
# 2024-09-30  260.600006
# 2024-10-31  270.000000
# 2024-11-30  346.299988
#
# [174 rows x 1 columns]

# %%
df_tsla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\1708041534.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tsla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# <Axes: xlabel='Date'>

# %%
df_tsla.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.074000  1.333333  1.055333  1.333333  103003500

# %%
df_tsla['High'].head()
# Out:
# Ticker          TSLA
# Date
# 2010-06-29  1.666667
# 2010-06-30  2.028000
# 2010-07-01  1.728000
# 2010-07-02  1.540000
# 2010-07-06  1.333333

# %%
df_tsla['High'].rolling(10) #Rolling of 10 days
## axis 0 i.e. we are doing it for column
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
df_tsla['High'].rolling(10).mean() ## On this rolling we are applying aggregate function and finding mean
## Here u are trying to find out rolling mean for 10 days
# Out:
# Ticker            TSLA
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# ...                ...
# 2024-11-13  298.506000
# 2024-11-14  305.529001
# 2024-11-15  312.597000
# 2024-11-18  322.562000
# 2024-11-19  331.772000
#
# [3624 rows x 1 columns]

# %%
df_tsla['High'].rolling(10).max()
# Out:
# Ticker            TSLA
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# ...                ...
# 2024-11-13  358.640015
# 2024-11-14  358.640015
# 2024-11-15  358.640015
# 2024-11-18  358.640015
# 2024-11-19  358.640015
#
# [3624 rows x 1 columns]

# %%
df_tsla['High'].rolling(10).mean().head(20) ## since its rolling mean for 10 , isliye usse pehle ki values NaN ho gyi
# Out:
# Ticker          TSLA
# Date
# 2010-06-29       NaN
# 2010-06-30       NaN
# 2010-07-01       NaN
# 2010-07-02       NaN
# 2010-07-06       NaN
# 2010-07-07       NaN
# 2010-07-08       NaN
# 2010-07-09       NaN
# 2010-07-12       NaN
# 2010-07-13  1.421333
# 2010-07-14  1.389000
# 2010-07-15  1.329533
# 2010-07-16  1.298733
# 2010-07-19  1.293067
# 2010-07-20  1.305400
# 2010-07-21  1.333867
# 2010-07-22  1.358733
# 2010-07-23  1.383133
# 2010-07-26  1.406000
# 2010-07-27  1.422933

# %%
df_tsla['High'].rolling(10).max().head(20)
# Out:
# Ticker          TSLA
# Date
# 2010-06-29       NaN
# 2010-06-30       NaN
# 2010-07-01       NaN
# 2010-07-02       NaN
# 2010-07-06       NaN
# 2010-07-07       NaN
# 2010-07-08       NaN
# 2010-07-09       NaN
# 2010-07-12       NaN
# 2010-07-13  2.028000
# 2010-07-14  2.028000
# 2010-07-15  1.728000
# 2010-07-16  1.540000
# 2010-07-19  1.483333
# 2010-07-20  1.483333
# 2010-07-21  1.483333
# 2010-07-22  1.483333
# 2010-07-23  1.483333
# 2010-07-26  1.483333
# 2010-07-27  1.483333

# %%
## Creating a new columns
df_tsla['Open:30 days rolling'] = df_tsla['Open'].rolling(30).mean()

# %%
df_tsla.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Vol
# 2010-07-07                  NaN
# 2010-07-08                  NaN
# 2010-07-09                  NaN
# 2010-07-12                  NaN
# 2010-07-13                  NaN
# 2010-07-14                  NaN
# 2010-07-15                  NaN
# 2010-07-16                  NaN
# 2010-07-19                  NaN
# 2010-07-20                  NaN
# 2010-07-21                  NaN
# 2010-07-22                  NaN
# 2010-07-23                  NaN
# 2010-07-26                  NaN
# 2010-07-27                  NaN
# 2010-07-28                  NaN
# 2010-07-29                  NaN
# 2010-07-30                  NaN
# 2010-08-02                  NaN
# 2010-08-03                  NaN
# 2010-08-04                  NaN
# 2010-08-05                  NaN
# 2010-08-06                  NaN
# 2010-08-09                  NaN
# 2010-08-10             1.357711
# 2010-08-11             1.357022
# 2010-08-12             1.339267

# %%
df_tsla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
## Note: with the help of rolling we can also do smoothening
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Rolling provides rolling windows calculation that's what we specifically do in moving average
# Orange line is the smoothened version of the blue line
# Whatever we discussed with respect to rolling window is specifically called mean average(which we got from rolling window).
# Next we will learn Exponentially weighted moving average(EWMA)
# Error trend seasonality(ETS).
# ARIMA
# ACF
# PACF
# Autocorrelation Plot
# Partial Autocorrelation Plot
# ARIMAX ,SARIMAX
# How to use FbProphet to do forecasting(library developed by facebook)

# %% [markdown]
# Basic idea of Time series data
# 1. Upward Trend
# 2. Stationanry Trend
# 3. Downward Trend
# 4. Cyclic Trend

# %% [markdown]
# Day 2 - Time Series
# 1. Simple Moving Average
# 2. Cummulative Moving Average
# 3. Exponential Weight Moving Average
# 4. Moving Average (Formula) --> ACF (AutoCorrelation Plot) (MA)
# 5. AutoRegreesive Model --> PACF (Partial AutoCorrelation) (AR)  Combine these two it becomes ARMA model
#
# Next Class : ARIMA,ARIMAX,SARIMAX

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
import yfinance as yf

# Fetch Tesla stock data
df_tsla = yf.download('TSLA')
df_tsla
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2010-06-29    1.592667    1.592667    1.666667    1.169333    1.266667
# 2010-06-30    1.588667    1.588667    2.028000    1.553333    1.719333
# 2010-07-01    1.464000    1.464000    1.728000    1.351333    1.666667
# 2010-07-02    1.280000    1.280000    1.540000    1.247333    1.533333
# 2010-07-06    1.074000    1.074000    1.333333    1.055333    1.333333
# ...                ...         ...         ...         ...         ...
# 2024-11-13  330.239990  330.239990  344.600006  322.500000  335.850006
# 2024-11-14  311.179993  311.179993  329.980011  310.369995  327.690002
# 2024-11-15  320.720001  320.720001  324.679993  309.220001  310.570007
# 2024-11-18  338.739990  338.739990  348.549988  330.010010  340.730011
# 2024-11-19  346.000000  346.000000  347.380005  332.750000  335.760010
#
# Price          Volume
# Ticker           TSLA
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# 2010-07-02   77097000
# 2010-07-06  103003500
# ...               ...
# 2024-11-13  125405600
# 2024-11-14  120726100
# 2024-11-15  114440300
# 2024-11-18  126547500
# 2024-11-19   88563400
#
# [3624 rows x 6 columns]

# %%
## Simple Moving Average
## Helps in smoothenning the curve (harr 5 instance ka average nikalna)

# %%
df_tsla['Open'].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla['Open:10 days rolling'] = df_tsla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tsla[['Open','Open:10 days rolling']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla[['Open','Open:10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# In financing why do people use it
# Curve me jab price low jaye then its the buy time for u and jab price high jaye then its sell time for you to earn the profit
# (This is why people use it in stock market and finance) Used only for short term
# U need not depend only on 10 windows , u can use any number of windows u want.

# %%
df_tsla['Open:30 days rolling'] = df_tsla['Open'].rolling(window=30,min_periods=1).mean()
df_tsla['Open:50 days rolling'] = df_tsla['Open'].rolling(window=50,min_periods=1).mean()

# %%
df_tsla[['Open','Open:10 days rolling','Open:30 days rolling','Open:50 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# As the window size is increasing in rolling the curve is becoming smoothen(simple moving average)
# Major Disadvantage of Simple Moving Average:
# 1. U are giving similiar importance to all the data , for all the data points based on the window size
# u are using the formula (x1 + x2 + x3 + x4 + x5)/5 only , where n = window size.
# In time series our main focus should be given to recent data a lot.
# I want to give more importance or can say more weight to the recent data , and that weight is basically provided by some parameters
# that we are going to see in EWMA(Exponentially Weighted Moving Average)
#
# 2. Cummulative Moving Average(CMA)
# if we have Open : 12 13 11 15 16 18
# Then in CMA we have : (12+13)/2 , (12+13+11)/3 , (12+13+11+15)/4 and this way u calculate CMA
# Very very easy u can use a function expanding to find it out.

# %%
## Expanding
# CMA
df_tsla['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# EWMA - Exponentially Weighted Moving Average
# Here our focus should be more on the current upcoming data or just on the recent data that we are having so that
# we can do the projection properly
# If u want to calculate EWMA with respect to t , then
# EMWA(t) = a * x(t) + (1-a) * EMWA(t-1) , here a is weight , through which u are giving priority to your
# first data instead of the previous one , this is specifically done to prevent any kind of lags.

# %%
#EMWA - Exponentially Weighted Moving Average or Exponential Moving Average

# %%
## EMA(Exponential moving average) tesla shares
# Lets's smoothing factor - 0.1
df_tsla['EMA_0.1'] = df_tsla['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
df_tsla[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla['EMA_0.3'] = df_tsla['Open'].ewm(alpha=0.3,adjust=False).mean()

# %%
df_tsla[['Open','EMA_0.1','EMA_0.3']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
## EWMA(Exponential weighted moving average) tesla shares
# U can do it with the help of span(in days)in ewm() function
df_tsla['EMA_5days'] = df_tsla['Open'].ewm(span=5).mean()

# %%
df_tsla[['Open','EMA_5days']].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla[['Open','EMA_0.1','EMA_5days']].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Which moving average is the best ?
# Exponential Weighted Moving Average is the best
#
# In ARIMA --> AR + I + MA
# AR - Auto Regreesion
# MA - Moving Average
# If u combine only these two , then it will specifically become ARMA model
# (ARMA model is good for forecasting specifically sales(monthly production), but is not good for stock predictions(waste of time))
# (No model is good for stocks)
#
# Interview Questions:
# For moving average do you use PACF plot or ACF plot ??
# Where is PACF used or where is ACF used ??

# %% [markdown]
# Moving Average Models
# Let's say my expectation w.r.t the people attending the live session is u = 10 (mean/average expectation)
# So if I want to calculate or create moving average models my formula will be like this :
# MA = u + Coefficient1 * Error term with respect to previous time stamp. Here my mean u = 10.
# This is how model does forecasting of future with your previous data. I have t-1 data , t-2 data then with these previous
# data we will be able to predict the future data values.

# %% [markdown]
# ARIMA and SAIMAX , 1st thing to understand - Autoregression 2nd Moving Average
# 3rd one Integrated (I of arima)
# Autoregression is specifically done by graph which is called PACF(Partial Autocorrelation)
# Moving Average is basically done by Auto-correlation plots
# Integrated value can be found out by diffrential
# We will find out all these values and based on these we will solve the problem

# %% [markdown]
# ARIMA
# Autoregression : Suppose i have dataset giving monthly sales of onions , let's say right now its april month
# then Jan Feb  March April
#     t-3  t-2   t-1   t
# In autoregression we are just trying to apply some regression algorithmns in order to find out that what
# may be the sale in may month. Here if my k value is 4 , then I will see my previous 4 months (this is called as lags),
# lags is u refering to ur previous months to find out the sales of ur next months. And each and every previous month
# may have a direct or indirect impact on the sales of next month.
# Regression algorithms : y = mx + c (now we apply this w.r.t timestamp)
# How do we define our k value ??
# Ot = B0 + B1*Ot-1 + B2*Ot-2 + B3*Ot-3 , here B1 , B2 , B3 are coefficients whichare helping to determine how much the
# values Ot-1 , Ot-2 .... are impacting Ot. (Lags basically means timestamp).
# PACF is giving correlation from a specific lag to the current timestamp. Graph: x me lags and y me PACF. Graph me it specifies
# a range , on both above and below axis (specifies upper bound and lower bound). (NOTE: Graphs are been plotted both above and
# below the x axis(parallel to x-axis)). The upper bound and lower bound basically specifies that if it is crossing the upper
# bound or lower bound , then that timestamp has some impact on the current timestamp(Useful in calculating the sales).If uss timestamp
# pe plotted hist ka height is below that range(upper or lower) ,then that time stamp has no correlation with the current timestamp.
# This is PACF graph. This PACF graph helps us to find out AutoCorrelation.
# (Do theory part in notebook , better to write for formulas and better understanding)

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sms
import pandas as pd
# %matplotlib inline

# %%
df_airline = pd.read_csv("C:/Users/Amritanshu Bhardwaj/Downloads/AirPassengers.csv")
df_airline.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df_airline.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
df_airline.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
df_airline.dropna(axis=0,inplace=True)

# %%
df_airline.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df_airline['Month'] = pd.to_datetime(df_airline['Month'])

# %%
df_airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
df_airline.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
df_airline.set_index('Month',inplace=True)

# %%
df_airline.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
df_airline.plot()  ##This looks like a seasonal data(Graphs moving continiously up and down)
## Our dataset should not be seasonal it should be stationanry
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result = adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p-value:{}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis,reject the null hypothesis.Data has no unit root and its stationary")
    else:
        print("Weak evidence against null hypothesis,time series has unit root,indicating it is non-stationary")

# %%
adf_test(df_airline["#Passengers"])
# Out:
# ADF Statistics: 0.8153688792060482
# p-value:0.991880243437641
# Weak evidence against null hypothesis,time series has unit root,indicating it is non-stationary

# %%
##Use Techniques Differencing(to make it stationary)(shifting by 1 as we are doing differencing by one day)
df_airline["Passengers First Difference"] = df_airline["#Passengers"] - df_airline["#Passengers"].shift(1)

# %%
df_airline.head()
# Out:
#             #Passengers  Passengers First Difference
# Month
# 1949-01-01          112                          NaN
# 1949-02-01          118                          6.0
# 1949-03-01          132                         14.0
# 1949-04-01          129                         -3.0
# 1949-05-01          121                         -8.0

# %%
adf_test(df_airline["Passengers First Difference"].dropna())
# Out:
# ADF Statistics: -2.8292668241699994
# p-value:0.0542132902838255
# Weak evidence against null hypothesis,time series has unit root,indicating it is non-stationary

# %%
## Still non-stationary do second differencing(u can also directly do it from #Passengers itself by doing shift of 2)
df_airline['Passengers Second Difference'] = df_airline['Passengers First Difference']-df_airline['Passengers First Difference'].shift(1)
##Lekin kyunki first difference se nikal rhe hai isliye shift of 1 hi kiya

# %%
adf_test(df_airline['Passengers Second Difference'].dropna())  ##Now it became stationary
# Out:
# ADF Statistics: -16.384231542468505
# p-value:2.7328918500142407e-29
# strong evidence against the null hypothesis,reject the null hypothesis.Data has no unit root and its stationary

# %%
## 12 months
## Use techniques Differencing
df_airline['Passengers 12 Difference'] = df_airline["#Passengers"]-df_airline["#Passengers"].shift(12)

# %%
adf_test(df_airline['Passengers 12 Difference'].dropna())
## If u have seasonal data go for this kind of 12 month difference
# Out:
# ADF Statistics: -3.383020726492481
# p-value:0.011551493085514954
# strong evidence against the null hypothesis,reject the null hypothesis.Data has no unit root and its stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf = plot_acf(df_airline['Passengers Second Difference'].dropna())
## With the help of ACF we calculate a parameter called as Q

# %%
acf_12 = plot_acf(df_airline['Passengers 12 Difference'].dropna())
## Here we are going to see seasonality(Note: For seasonal data use SARIMAX only)
## Here Q value is 5 , as 5 are beyond the bounds , i.e. creating impacts (here we are not considering 0th position on x-axis)
## We don't count for 0.

# %%
result = plot_pacf(df_airline['Passengers Second Difference'].dropna())

# %%
pacf_12 = plot_pacf(df_airline['Passengers 12 Difference'].dropna())

# %%
## Split train and test data
df_airline
# Out:
#             #Passengers  Passengers First Difference  \
# Month
# 1949-01-01          112                          NaN
# 1949-02-01          118                          6.0
# 1949-03-01          132                         14.0
# 1949-04-01          129                         -3.0
# 1949-05-01          121                         -8.0
# ...                 ...                          ...
# 1960-08-01          606                        -16.0
# 1960-09-01          508                        -98.0
# 1960-10-01          461                        -47.0
# 1960-11-01          390                        -71.0
# 1960-12-01          432                         42.0
#
#             Passengers Second Difference  Passengers 12 Difference
# Month
# 1949-01-01                           NaN                       NaN
# 1949-02-01                           NaN                       NaN
# 1949-03-01                           8.0                       NaN
# 1949-04-01                         -17.0                       NaN
# 1949-05-01                          -5.0                       NaN
# ...                                  ...                       ...
# 1960-08-01                        -103.0                      47.0
# 1960-09-01                         -82.0                      45.0
# 1960-10-01                          51.0                      54.0
# 1960-11-01                         -24.0                      28.0
# 1960-12-01                         113.0                      27.0
#
# [144 rows x 4 columns]

# %%
from datetime import datetime,timedelta
train_dataset_end = datetime(1955,12,1)
test_dataset_end = datetime(1960,12,1)

# %% [markdown]
# With Help of ACF u are performing Moving Average , u find out q value
# With the help of PACF u are performing auto regression , u find out p value

# %%
train_data = df_airline[:train_dataset_end]
test_data = df_airline[train_dataset_end + timedelta(days=1):test_dataset_end]

# %%
## Prediction
pred_start = test_data.index[0]
pred_end = test_data.index[-1]

# %%
test_data
# Out:
#             #Passengers  Passengers First Difference  \
# Month
# 1956-01-01          284                          6.0
# 1956-02-01          277                         -7.0
# 1956-03-01          317                         40.0
# 1956-04-01          313                         -4.0
# 1956-05-01          318                          5.0
# 1956-06-01          374                         56.0
# 1956-07-01          413                         39.0
# 1956-08-01          405                         -8.0
# 1956-09-01          355                        -50.0
# 1956-10-01          306                        -49.0
# 1956-11-01          271                        -35.0
# 1956-12-01          306                         35.0
# 1957-01-01          315                          9.0
# 1957-02-01          301                        -14.0
# 1957-03-01          356                         55.0
# 1957-04-01          348                         -8.0
# 1957-05-01          355                          7.0
# 1957-06-01          422                         67.0
# 1957-07-01          465                         43.0
# 1957-08-01          467                          2.0
# 1957-09-01          404                        -63.0
# 1957-10-01          347                        -57.0
# 1957-11-01          305                        -42.0
# 1957-12-01          336                         31.0
# 1958-01-01          340                          4.0
# 1958-02-01          318                        -22.0
# 1958-03-01          362                         44.0
# 1958-04-01          348                        -14.0
# 1958-05-01          363                         15.0
# 1958-06-01          435                         72.0
# 1958-07-01          491                         56.0
# 1958-08-01          505                         14.0
# 1958-09-01          404                       -101.0
# 1958-10-01          359                        -45.0
# 1958-11-01          310                        -49.0
# 1958-12-01          337                         27.0
# 1959-01-01          360                         23.0
# 1959-02-01          342                        -18.0
# 1959-03-01          406                         64.0
# 1959-04-01          396                        -10.0
# 1959-05-01          420                         24.0
# 1959-06-01          472                         52.0
# 1959-07-01          548                         76.0
# 1959-08-01          559                         11.0
# 1959-09-01          463                        -96.0
# 1959-10-01          407                        -56.0
# 1959-11-01          362                        -45.0
# 1959-12-01          405                         43.0
# 1960-01-01          417                         12.0
# 1960-02-01          391                        -26.0
# 1960-03-01          419                         28.0
# 1960-04-01          461                         42.0
# 1960-05-01          472                         11.0
# 1960-06-01          535                         63.0
# 1960-07-01          622                         87.0
# 1960-08-01          606                        -16.0
# 1960-09-01          508                        -98.0
# 1960-10-01          461                        -47.0
# 1960-11-01          390                        -71.0
# 1960-12-01          432                         42.0
#
#             Passengers Second Difference  Passengers 12 Difference
# Month
# 1956-01-01                         -35.0                      42.0
# 1956-02-01                         -13.0                      44.0
# 1956-03-01                          47.0                      50.0
# 1956-04-01                         -44.0                      44.0
# 1956-05-01                           9.0                      48.0
# 1956-06-01                          51.0                      59.0
# 1956-07-01                         -17.0                      49.0
# 1956-08-01                         -47.0                      58.0
# 1956-09-01                         -42.0                      43.0
# 1956-10-01                           1.0                      32.0
# 1956-11-01                          14.0                      34.0
# 1956-12-01                          70.0                      28.0
# 1957-01-01                         -26.0                      31.0
# 1957-02-01                         -23.0                      24.0
# 1957-03-01                          69.0                      39.0
# 1957-04-01                         -63.0                      35.0
# 1957-05-01                          15.0                      37.0
# 1957-06-01                          60.0                      48.0
# 1957-07-01                         -24.0                      52.0
# 1957-08-01                         -41.0                      62.0
# 1957-09-01                         -65.0                      49.0
# 1957-10-01                           6.0                      41.0
# 1957-11-01                          15.0                      34.0
# 1957-12-01                          73.0                      30.0
# 1958-01-01                         -27.0                      25.0
# 1958-02-01                         -26.0                      17.0
# 1958-03-01                          66.0                       6.0
# 1958-04-01                         -58.0                       0.0
# 1958-05-01                          29.0                       8.0
# 1958-06-01                          57.0                      13.0
# 1958-07-01                         -16.0                      26.0
# 1958-08-01                         -42.0                      38.0
# 1958-09-01                        -115.0                       0.0
# 1958-10-01                          56.0                      12.0
# 1958-11-01                          -4.0                       5.0
# 1958-12-01                          76.0                       1.0
# 1959-01-01                          -4.0                      20.0
# 1959-02-01                         -41.0                      24.0
# 1959-03-01                          82.0                      44.0
# 1959-04-01                         -74.0                      48.0
# 1959-05-01                          34.0                      57.0
# 1959-06-01                          28.0                      37.0
# 1959-07-01                          24.0                      57.0
# 1959-08-01                         -65.0                      54.0
# 1959-09-01                        -107.0                      59.0
# 1959-10-01                          40.0                      48.0
# 1959-11-01                          11.0                      52.0
# 1959-12-01                          88.0                      68.0
# 1960-01-01                         -31.0                      57.0
# 1960-02-01                         -38.0                      49.0
# 1960-03-01                          54.0                      13.0
# 1960-04-01                          14.0                      65.0
# 1960-05-01                         -31.0                      52.0
# 1960-06-01                          52.0                      63.0
# 1960-07-01                          24.0                      74.0
# 1960-08-01                        -103.0                      47.0
# 1960-09-01                         -82.0                      45.0
# 1960-10-01                          51.0                      54.0
# 1960-11-01                         -24.0                      28.0
# 1960-12-01                         113.0                      27.0

# %%
## Create a ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# %%
train_data
# Out:
#             #Passengers  Passengers First Difference  \
# Month
# 1949-01-01          112                          NaN
# 1949-02-01          118                          6.0
# 1949-03-01          132                         14.0
# 1949-04-01          129                         -3.0
# 1949-05-01          121                         -8.0
# ...                 ...                          ...
# 1955-08-01          347                        -17.0
# 1955-09-01          312                        -35.0
# 1955-10-01          274                        -38.0
# 1955-11-01          237                        -37.0
# 1955-12-01          278                         41.0
#
#             Passengers Second Difference  Passengers 12 Difference
# Month
# 1949-01-01                           NaN                       NaN
# 1949-02-01                           NaN                       NaN
# 1949-03-01                           8.0                       NaN
# 1949-04-01                         -17.0                       NaN
# 1949-05-01                          -5.0                       NaN
# ...                                  ...                       ...
# 1955-08-01                         -66.0                      54.0
# 1955-09-01                         -18.0                      53.0
# 1955-10-01                          -3.0                      45.0
# 1955-11-01                           1.0                      34.0
# 1955-12-01                          78.0                      49.0
#
# [84 rows x 4 columns]

# %%
model_ARIMA = ARIMA(train_data['#Passengers'],order=(10,2,12)) 
## 10 denotes p value when we plotted pacf curve for two time differencing(kha se we could take so that its highly crossing bounds)
# , 2 - denotes how many time we did differencing
## ,probably two times (this is not for seasonal , where we did differencing of 12) , 12 is q value in acf curve for 
## two differencing , 0th ko chor kar kha se highly bound cross hua(12 th data having a high impact)
#(p,d,q)  q is moving average , while p from pacf is auto correlation
# Out:
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_Arima_fit = model_ARIMA.fit()
# Out:
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_Arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            #Passengers   No. Observations:                   84
# Model:               ARIMA(10, 2, 12)   Log Likelihood                -307.732
# Date:                Wed, 20 Nov 2024   AIC                            661.463
# Time:                        23:17:53   BIC                            716.818
# Sample:                    01-01-1949   HQIC                           683.687
#                          - 12-01-1955
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0467      0.115      0.408      0.683      -0.178       0.271
# ar.L2         -1.0428      0.083    -12.492      0.000      -1.206      -0.879
# ar.L3          0.0884      0.139      0.638      0.523      -0.183       0.360
# ar.L4         -1.0255      0.131     -7.834      0.000      -1.282      -0.769
# ar.L5          0.0655      0.155      0.423      0.673      -0.238       0.370
# ar.L6         -0.9857      0.143     -6.874      0.000      -1.267      -0.705
# ar.L7          0.0173      0.142      0.122      0.903      -0.261       0.296
# ar.L8         -0.9821      0.123     -8.010      0.000      -1.222      -0.742
# ar.L9         -0.0070      0.095     -0.073      0.942      -0.193       0.179
# ar.L10        -0.9389      0.085    -11.073      0.000      -1.105      -0.773
# ma.L1         -1.2856      0.254     -5.061      0.000      -1.783      -0.788
# ma.L2          1.2389      0.358      3.458      0.001       0.537       1.941
# ma.L3         -1.4405      0.436     -3.306      0.001      -2.295      -0.586
# ma.L4          1.3744      0.506      2.716      0.007       0.383       2.366
# ma.L5         -1.2148      0.574     -2.118      0.034      -2.339      -0.091
# ma.L6          1.0820      0.660      1.641      0.101      -0.211       2.375
# ma.L7         -1.0691      0.714     -1.496      0.135      -2.469       0.331
# ma.L8          0.8852      0.819      1.081      0.280      -0.720       2.490
# ma.L9         -0.7847      0.737     -1.065      0.287      -2.228       0.659
# ma.L10         0.5233      0.601      0.870      0.384      -0.655       1.702
# ma.L11        -0.4133      0.455     -0.908      0.364      -1.305       0.478
# ma.L12         0.1336      0.273      0.489      0.625      -0.402       0.669
# sigma2        77.2058     16.190      4.769      0.000      45.475     108.937
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 4.73
# Prob(Q):                              0.99   Prob(JB):                         0.09
# Heteroskedasticity (H):               2.12   Skew:                             0.59
# Prob(H) (two-sided):                  0.06   Kurtosis:                         2.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
## Prediction
pred_start_date = test_data.index[0]
pred_end_date = test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred = model_Arima_fit.predict(start = pred_start_date,end = pred_end_date)
residuals = test_data['#Passengers']-pred

# %%
residuals
# Out:
# Month
# 1956-01-01      0.750961
# 1956-02-01      7.499445
# 1956-03-01     21.833213
# 1956-04-01     14.429763
# 1956-05-01     18.901991
# 1956-06-01     28.647282
# 1956-07-01     24.511844
# 1956-08-01     33.109815
# 1956-09-01     14.928483
# 1956-10-01      3.086451
# 1956-11-01     -0.822303
# 1956-12-01      3.360026
# 1957-01-01      3.913295
# 1957-02-01      7.216374
# 1957-03-01     39.077663
# 1957-04-01     23.512499
# 1957-05-01     28.904789
# 1957-06-01     49.305086
# 1957-07-01     50.435487
# 1957-08-01     70.445895
# 1957-09-01     38.720004
# 1957-10-01     14.748454
# 1957-11-01      2.457573
# 1957-12-01      6.521508
# 1958-01-01      1.446040
# 1958-02-01     -0.367677
# 1958-03-01     23.108393
# 1958-04-01     -2.478944
# 1958-05-01      9.780271
# 1958-06-01     35.438482
# 1958-07-01     50.498697
# 1958-08-01     83.701187
# 1958-09-01     13.343234
# 1958-10-01     -2.619052
# 1958-11-01    -23.219105
# 1958-12-01    -19.321170
# 1959-01-01     -5.705154
# 1959-02-01     -1.224045
# 1959-03-01     44.893597
# 1959-04-01     19.495196
# 1959-05-01     39.553166
# 1959-06-01     45.992088
# 1959-07-01     81.723338
# 1959-08-01    112.841355
# 1959-09-01     46.818990
# 1959-10-01     16.002050
# 1959-11-01     -1.843909
# 1959-12-01     21.841254
# 1960-01-01     24.412146
# 1960-02-01     22.670028
# 1960-03-01     35.411884
# 1960-04-01     58.465101
# 1960-05-01     64.249865
# 1960-06-01     82.912633
# 1960-07-01    130.124602
# 1960-08-01    134.843216
# 1960-09-01     66.160769
# 1960-10-01     40.633430
# 1960-11-01     -4.411001
# 1960-12-01     22.014527
# dtype: float64

# %%
model_Arima_fit.resid.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
test_data['Predicted_ARIMA'] = pred
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\284031954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_ARIMA'] = pred

# %%
test_data[['#Passengers','Predicted_ARIMA']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
acf12 = plot_acf(df_airline['Passengers 12 Difference'].dropna())
pacf12 = plot_pacf(df_airline['Passengers 12 Difference'].dropna())

# %%
## Create a SARIMA model
from statsmodels.tsa.statespace.sarimax import SARIMAX
## sarima is for seasonal data

# %%
model_SARIMA = SARIMAX(train_data['#Passengers'],order=(3,0,5),seasonal_order=(0,1,0,12))
# p = 3 , as bound passing and in middle is 3 in partial autocorrelation me.
# d = 0 , as this is sarimax for seasonal
# q = 5 , as 5 is in close to middle and crossing the bound in autocorrelation
# Out:
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_SARIMA_fit = model_SARIMA.fit()
# Out:
# c:\Users\Amritanshu Bhardwaj\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_SARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                         #Passengers   No. Observations:                   84
# Model:             SARIMAX(3, 0, 5)x(0, 1, [], 12)   Log Likelihood                -265.240
# Date:                             Wed, 20 Nov 2024   AIC                            548.481
# Time:                                     23:51:46   BIC                            568.971
# Sample:                                 01-01-1949   HQIC                           556.638
#                                       - 12-01-1955
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5983      0.937      0.638      0.523      -1.239       2.436
# ar.L2          0.8311      0.232      3.581      0.000       0.376       1.286
# ar.L3         -0.4525      0.894     -0.506      0.613      -2.204       1.299
# ma.L1          0.1837      1.165      0.158      0.875      -2.099       2.467
# ma.L2         -0.5341      1.263     -0.423      0.672      -3.009       1.940
# ma.L3         -0.0986      0.384     -0.257      0.798      -0.852       0.655
# ma.L4         -0.1273      0.338     -0.377      0.706      -0.789       0.535
# ma.L5          0.2471      0.357      0.693      0.489      -0.452       0.947
# sigma2        87.7323     81.217      1.080      0.280     -71.451     246.915
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 2.68
# Prob(Q):                              0.88   Prob(JB):                         0.26
# Heteroskedasticity (H):               2.05   Skew:                             0.46
# Prob(H) (two-sided):                  0.09   Kurtosis:                         2.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_data.tail()
# Out:
#             #Passengers  Passengers First Difference  \
# Month
# 1960-08-01          606                        -16.0
# 1960-09-01          508                        -98.0
# 1960-10-01          461                        -47.0
# 1960-11-01          390                        -71.0
# 1960-12-01          432                         42.0
#
#             Passengers Second Difference  Passengers 12 Difference  \
# Month
# 1960-08-01                        -103.0                      47.0
# 1960-09-01                         -82.0                      45.0
# 1960-10-01                          51.0                      54.0
# 1960-11-01                         -24.0                      28.0
# 1960-12-01                         113.0                      27.0
#
#             Predicted_ARIMA
# Month
# 1960-08-01       471.156784
# 1960-09-01       441.839231
# 1960-10-01       420.366570
# 1960-11-01       394.411001
# 1960-12-01       409.985473

# %%
#prediction
pred_start = test_data.index[0]
pred_end_date = test_data.index[-1]
print(pred_start_date)
print(pred_end_date)
# Out:
# 1956-01-01 00:00:00
# 1960-12-01 00:00:00

# %%
pred_SARIMA = model_SARIMA_fit.predict(start=datetime(1956,6,6),end=datetime(1960,12,1))
residuals = test_data['#Passengers']-pred_SARIMA

# %%
model_SARIMA_fit.resid.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
model_SARIMA_fit.resid.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
test_data['Predicted_SARIMA'] = pred_SARIMA
# Out:
# C:\Users\Amritanshu Bhardwaj\AppData\Local\Temp\ipykernel_12996\4184489146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_SARIMA'] = pred_SARIMA

# %%
test_data
# Out:
#             #Passengers  Passengers First Difference  \
# Month
# 1956-01-01          284                          6.0
# 1956-02-01          277                         -7.0
# 1956-03-01          317                         40.0
# 1956-04-01          313                         -4.0
# 1956-05-01          318                          5.0
# 1956-06-01          374                         56.0
# 1956-07-01          413                         39.0
# 1956-08-01          405                         -8.0
# 1956-09-01          355                        -50.0
# 1956-10-01          306                        -49.0
# 1956-11-01          271                        -35.0
# 1956-12-01          306                         35.0
# 1957-01-01          315                          9.0
# 1957-02-01          301                        -14.0
# 1957-03-01          356                         55.0
# 1957-04-01          348                         -8.0
# 1957-05-01          355                          7.0
# 1957-06-01          422                         67.0
# 1957-07-01          465                         43.0
# 1957-08-01          467                          2.0
# 1957-09-01          404                        -63.0
# 1957-10-01          347                        -57.0
# 1957-11-01          305                        -42.0
# 1957-12-01          336                         31.0
# 1958-01-01          340                          4.0
# 1958-02-01          318                        -22.0
# 1958-03-01          362                         44.0
# 1958-04-01          348                        -14.0
# 1958-05-01          363                         15.0
# 1958-06-01          435                         72.0
# 1958-07-01          491                         56.0
# 1958-08-01          505                         14.0
# 1958-09-01          404                       -101.0
